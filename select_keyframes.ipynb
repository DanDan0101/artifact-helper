# %%
import imageio.v3 as iio
import numpy as np
from matplotlib import pyplot as plt

# %%
frames = iio.imread("samples/artifacts_short.mkv", index=0, plugin="pyav")

# %%
frames.shape
# Out:
# (2160, 3240, 3)

# %%
fig = plt.figure(dpi=300)
plt.imshow(frames)
