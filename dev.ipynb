# %%
from pathlib import Path

import numpy as np
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm

import imageio.v3 as iio

from artifact_helper.preprocessing import n_frames, crop_frame, find_keyframes

# %%
dir = "media"
file_name = "artifacts_long.mkv"
file_path = Path(f"./{dir}/{file_name}")

# %%
for path in Path(f"./{dir}").glob("*.mkv"):
    print(f"{path} has {n_frames(path)} frames")
# Out:
# samples\artifacts_long.mkv has 703 frames
# samples\artifacts_short.mkv has 138 frames
# samples\weapons.mkv has 96 frames

# %%
peaks = find_keyframes(file_path)
print(f"Detected {peaks.shape[0]} unique artifacts in {file_name}.")
# Out:
# Finding keyframes: 100%|██████████| 703/703 [00:04<00:00, 144.34frames/s]
# Detected 80 unique artifacts in artifacts_long.mkv.

# %%
peaks
# Out:
# array([  0,   5,  12,  21,  30,  39,  47,  55,  64,  73,  82,  90,  99,
#        107, 115, 123, 132, 140, 148, 156, 165, 172, 180, 188, 196, 205,
#        213, 222, 231, 240, 248, 257, 268, 276, 284, 293, 302, 310, 318,
#        326, 334, 343, 352, 361, 370, 379, 388, 397, 432, 439, 446, 454,
#        462, 469, 477, 484, 492, 501, 511, 518, 527, 536, 545, 553, 562,
#        569, 577, 585, 595, 603, 612, 621, 628, 638, 648, 656, 665, 676,
#        685, 693])
